# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

print("Libraries loaded successfully!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Libraries loaded successfully!

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'sales_analysis.ipynb']

# %%
df = pd.read_csv("sales_data_sample.csv", encoding="latin1")
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...

# %%
df["STATUS"].unique()
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
df["SALES"].sum()
# Out:
# np.float64(10032628.85)

# %%
df["SALES"].mean()
# Out:
# np.float64(3553.889071909316)

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["SALES"], kde=True)
plt.title("Sales Distribution")
plt.show()

# %%
df.groupby("YEAR_ID")["SALES"].sum()
# Out:
# YEAR_ID
# 2003    3516979.54
# 2004    4724162.60
# 2005    1791486.71
# Name: SALES, dtype: float64

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="YEAR_ID", y="SALES", data=df, estimator=sum, palette="viridis")
plt.title("Revenue by Year")
plt.ylabel("Total Sales")
plt.show()
# Out:
# C:\Users\balap\AppData\Local\Temp\ipykernel_14792\3812412814.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="YEAR_ID", y="SALES", data=df, estimator=sum, palette="viridis")

# %%
monthly_sales = df.groupby("MONTH_ID")["SALES"].sum()
monthly_sales
# Out:
# MONTH_ID
# 1      785874.44
# 2      810441.90
# 3      754501.39
# 4      669390.96
# 5      923972.56
# 6      454756.78
# 7      514875.97
# 8      659310.57
# 9      584724.27
# 10    1121215.22
# 11    2118885.67
# 12     634679.12
# Name: SALES, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="MONTH_ID", y="SALES", data=df, estimator=sum, marker="o")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid(True)
plt.show()

# %%
country_sales = df.groupby("COUNTRY")["SALES"].sum().sort_values(ascending=False).head(10)
country_sales
# Out:
# COUNTRY
# USA          3627982.83
# Spain        1215686.92
# France       1110916.52
# Australia     630623.10
# UK            478880.46
# Italy         374674.31
# Finland       329581.91
# Norway        307463.70
# Singapore     288488.41
# Denmark       245637.15
# Name: SALES, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=country_sales.values, y=country_sales.index, palette="viridis")
plt.title("Top 10 Countries by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Country")
plt.show()
# Out:
# C:\Users\balap\AppData\Local\Temp\ipykernel_14792\2078070214.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_sales.values, y=country_sales.index, palette="viridis")

# %%
product_sales = df.groupby("PRODUCTLINE")["SALES"].sum().sort_values(ascending=False)
product_sales
# Out:
# PRODUCTLINE
# Classic Cars        3919615.66
# Vintage Cars        1903150.84
# Motorcycles         1166388.34
# Trucks and Buses    1127789.84
# Planes               975003.57
# Ships                714437.13
# Trains               226243.47
# Name: SALES, dtype: float64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=product_sales.index, y=product_sales.values, palette="viridis")
plt.title("Sales by Product Line")
plt.xlabel("Product Line")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\balap\AppData\Local\Temp\ipykernel_14792\981942635.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_sales.index, y=product_sales.values, palette="viridis")

# %%
customer_sales = df.groupby("CUSTOMERNAME")["SALES"].sum().sort_values(ascending=False)
customer_sales.head(10)
# Out:
# CUSTOMERNAME
# Euro Shopping Channel           912294.11
# Mini Gifts Distributors Ltd.    654858.06
# Australian Collectors, Co.      200995.41
# Muscle Machine Inc              197736.94
# La Rochelle Gifts               180124.90
# Dragon Souveniers, Ltd.         172989.68
# Land of Toys Inc.               164069.44
# The Sharp Gifts Warehouse       160010.27
# AV Stores, Co.                  157807.81
# Anna's Decorations, Ltd         153996.13
# Name: SALES, dtype: float64

# %%
top_customers = customer_sales.head(10)

plt.figure(figsize=(12,5))
sns.barplot(x=top_customers.values, y=top_customers.index, palette="viridis")
plt.title("Top 10 Customers by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Customer Name")
plt.show()
# Out:
# C:\Users\balap\AppData\Local\Temp\ipykernel_14792\1354319309.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_customers.values, y=top_customers.index, palette="viridis")

# %%
country_sales = df.groupby("COUNTRY")["SALES"].sum().sort_values(ascending=False)
country_sales.head(10)
# Out:
# COUNTRY
# USA          3627982.83
# Spain        1215686.92
# France       1110916.52
# Australia     630623.10
# UK            478880.46
# Italy         374674.31
# Finland       329581.91
# Norway        307463.70
# Singapore     288488.41
# Denmark       245637.15
# Name: SALES, dtype: float64

# %%
top_countries = country_sales.head(10)

plt.figure(figsize=(12,5))
sns.barplot(x=top_countries.values, y=top_countries.index, palette="viridis")
plt.title("Top 10 Countries by Total Sales")
plt.xlabel("Total Sales")
plt.ylabel("Country")
plt.show()
# Out:
# C:\Users\balap\AppData\Local\Temp\ipykernel_14792\2065831542.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette="viridis")

# %%
region_sales = df.groupby("TERRITORY")["SALES"].sum().sort_values(ascending=False)
region_sales
# Out:
# TERRITORY
# EMEA     4979272.41
# APAC      746121.83
# Japan     455173.22
# Name: SALES, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=region_sales.values, y=region_sales.index, palette="viridis")
plt.title("Sales by Territory")
plt.xlabel("Total Sales")
plt.ylabel("Territory")
plt.show()
# Out:
# C:\Users\balap\AppData\Local\Temp\ipykernel_14792\516755424.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_sales.values, y=region_sales.index, palette="viridis")

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# M
# # ⭐ Sales Data Analysis – Key Insights Summary
#
# ## 1️⃣ Yearly Sales Performance
# - **2004** achieved the highest total sales.
# - **2005** saw a major drop compared to 2003 and 2004.
#
# ## 2️⃣ Monthly Sales Trend
# - Sales peak in **October & November** (Holiday season).
# - Slowest months: **June & December**.
#
# ## 3️⃣ Product Line Performance
# - **Classic Cars** generate the highest revenue.
# - **Trains** generate the least revenue.
# - Big gap between top and bottom product lines.
#
# ## 4️⃣ Top 10 Countries by Sales
# - **USA** leads with the highest total revenue.
# - Followed by **Spain, France, Australia, and UK**.mmm
#
# ## 5️⃣ Top Customers
# - Euro Shopping Channel is the top customer.
# - Followed by Mini Gifts, Australian Collectors, etc.
